# %%
# !pip install ib_insync

# %%
from ib_insync import IB, util

util.startLoop()  # <- clave en notebooks/entornos interactivos

ib = IB()
ib.connect('127.0.0.1', 4002, clientId=1)

print("Connected:", ib.isConnected())
print("Server time:", ib.reqCurrentTime())

ib.disconnect()
# Out:
# Connected: True
# Server time: 2025-12-19 16:33:22+00:00

# %%
# !pip install fastapi uvicorn ib_insync
# Out:
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 22.4 MB/s  0:00:00
# ...
#
#    -------------------- ------------------- 4/8 [uvicorn]
#    -------------------- ------------------- 4/8 [uvicorn]
#    ------------------------- -------------- 5/8 [starlette]
#    ------------------------------ --------- 6/8 [pydantic]
#    ------------------------------ --------- 6/8 [pydantic]
#    ------------------------------ --------- 6/8 [pydantic]
#    ------------------------------ --------- 6/8 [pydantic]
#    ------------------------------ --------- 6/8 [pydantic]
#    ----------------------------------- ---- 7/8 [fastapi]
#    ----------------------------------- ---- 7/8 [fastapi]
#    ---------------------------------------- 8/8 [fastapi]
#
# ...
